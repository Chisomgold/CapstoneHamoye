# %%
#importing potentially useful libraries
import pandas as pd
import numpy as np
import seaborn as sns
sns.set()
import warnings #to remove warnings while working with the data
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#importing and loading dataset
#displaying all rows and columns for observation
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
gt = pd.read_csv('globalterrorism.csv')
gt.head(15)
# Out:
#          eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0   197000000001   1970       7     2        NaN         0        NaN
# 1   197000000002   1970       0     0        NaN         0        NaN
# 2   197001000001   1970       1     0        NaN         0        NaN
# 3   197001000002   1970       1     0        NaN         0        NaN
# 4   197001000003   1970       1     0        NaN         0        NaN
# 5   197001010002   1970       1     1        NaN         0        NaN
# 6   197001020001   1970       1     2        NaN         0        NaN
# 7   197001020002   1970       1     2        NaN         0        NaN
# 8   197001020003   1970       1     2        NaN         0        NaN
# 9   197001030001   1970       1     3        NaN         0        NaN
# 10  197001050001   1970       1     1        NaN         0        NaN
# 11  197001060001   1970       1     6        NaN         0        NaN
# 12  197001080001   1970       1     8        NaN         0        NaN
# 13  197001090001   1970       1     9        NaN         0        NaN
# 14  197001090002   1970       1     9        NaN         0        NaN
#
#     country         country_txt  region                   region_txt  \
# 0        58  Dominican Republic       2  Central America & Caribbean
# 1       130              Mexico       1                North America
# 2       160         Philippines       5               Southeast Asia
# 3        78              Greece       8               Western Europe
# 4       101               Japan       4                    East Asia
# 5       217       United States       1                North America
# 6       218             Uruguay       3                South America
# 7       217       United States       1                North America
# 8       217       United States       1                North America
# 9       217       United States       1                North America
# 10      217       United States       1                North America
# 11      217       United States       1                North America
# 12       98               Italy       8               Western Europe
# 13      217       United States       1                North America
# 14      217       United States       1                North America
#
#       provstate           city   latitude   longitude  specificity  vicinity  \
# 0           NaN  Santo Domingo  18.456792  -69.951164          1.0         0
# 1       Federal    Mexico city  19.371887  -99.086624          1.0         0
# 2        Tarlac        Unknown  15.478598  120.599741          4.0         0
# 3        Attica         Athens  37.997490   23.762728          1.0         0
# 4       Fukouka        Fukouka  33.580412  130.396361          1.0         0
# 5      Illinois          Cairo  37.005105  -89.176269          1.0         0
# 6    Montevideo     Montevideo -34.891151  -56.187214          1.0         0
# 7    California        Oakland  37.791927 -122.225906          1.0         0
# 8     Wisconsin        Madison  43.076592  -89.412488          1.0         0
# 9     Wisconsin        Madison  43.072950  -89.386694          1.0         0
# 10    Wisconsin        Baraboo  43.468500  -89.744299          1.0         0
# 11     Colorado         Denver  39.758968 -104.876305          1.0         0
# 12        Lazio           Rome  41.890961   12.490069          1.0         0
# 13     Michigan        Detroit  42.331685  -83.047924          1.0         0
# 14  Puerto Rico    Rio Piedras  18.386932  -66.061127          1.0         0
#
#                    location  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# 5                       NaN
# 6                       NaN
# 7           Edes Substation
# 8                       NaN
# 9                       NaN
# 10                      NaN
# 11                      NaN
# 12                      NaN
# 13                      NaN
# 14  Caparra Shopping Center
#
#                                               summary  crit1  crit2  crit3  \
# 0                                                 NaN      1      1      1
# 1                                                 NaN      1      1      1
# 2                                                 NaN      1      1      1
# 3                                                 NaN      1      1      1
# 4                                                 NaN      1      1      1
# 5   1/1/1970: Unknown African American assailants ...      1      1      1
# 6                                                 NaN      1      1      1
# 7   1/2/1970: Unknown perpetrators detonated explo...      1      1      1
# 8   1/2/1970: Karl Armstrong, a member of the New ...      1      1      1
# 9   1/3/1970: Karl Armstrong, a member of the New ...      1      1      1
# 10                                                NaN      1      1      0
# 11  1/6/1970: Unknown perpetrators threw a Molotov...      1      1      1
# 12                                                NaN      1      1      1
# 13  1/9/1970: Unknown perpetrators set off a fireb...      1      1      1
# 14  1/9/1970:  The Armed Commandos of Liberation c...      1      1      1
#
#     doubtterr  alternative             alternative_txt  multiple  success  \
# 0         0.0          NaN                         NaN       0.0        1
# 1         0.0          NaN                         NaN       0.0        1
# 2         0.0          NaN                         NaN       0.0        1
# 3         0.0          NaN                         NaN       0.0        1
# 4        -9.0          NaN                         NaN       0.0        1
# 5         0.0          NaN                         NaN       0.0        1
# 6         0.0          NaN                         NaN       0.0        0
# 7         1.0          2.0            Other Crime Type       0.0        1
# 8         0.0          NaN                         NaN       0.0        1
# 9         0.0          NaN                         NaN       0.0        1
# 10        1.0          1.0  Insurgency/Guerilla Action       0.0        0
# 11        1.0          2.0            Other Crime Type       0.0        1
# 12       -9.0          NaN                         NaN       0.0        1
# 13        0.0          NaN                         NaN       0.0        1
# 14        1.0          2.0            Other Crime Type       0.0        1
#
#     suicide  attacktype1                 attacktype1_txt  attacktype2  \
# 0         0            1                   Assassination          NaN
# 1         0            6     Hostage Taking (Kidnapping)          NaN
# 2         0            1                   Assassination          NaN
# 3         0            3               Bombing/Explosion          NaN
# 4         0            7  Facility/Infrastructure Attack          NaN
# 5         0            2                   Armed Assault          NaN
# 6         0            1                   Assassination          NaN
# 7         0            3               Bombing/Explosion          NaN
# 8         0            7  Facility/Infrastructure Attack          NaN
# 9         0            7  Facility/Infrastructure Attack          NaN
# 10        0            3               Bombing/Explosion          NaN
# 11        0            7  Facility/Infrastructure Attack          NaN
# 12        0            4                       Hijacking          NaN
# 13        0            7  Facility/Infrastructure Attack          NaN
# 14        0            7  Facility/Infrastructure Attack          NaN
#
#    attacktype2_txt  attacktype3 attacktype3_txt  targtype1  \
# 0              NaN          NaN             NaN         14
# 1              NaN          NaN             NaN          7
# 2              NaN          NaN             NaN         10
# 3              NaN          NaN             NaN          7
# 4              NaN          NaN             NaN          7
# 5              NaN          NaN             NaN          3
# 6              NaN          NaN             NaN          3
# 7              NaN          NaN             NaN         21
# 8              NaN          NaN             NaN          4
# 9              NaN          NaN             NaN          2
# 10             NaN          NaN             NaN          4
# 11             NaN          NaN             NaN          4
# 12             NaN          NaN             NaN          6
# 13             NaN          NaN             NaN          2
# 14             NaN          NaN             NaN          1
#
#                   targtype1_txt  targsubtype1  \
# 0   Private Citizens & Property          68.0
# 1       Government (Diplomatic)          45.0
# 2           Journalists & Media          54.0
# 3       Government (Diplomatic)          46.0
# 4       Government (Diplomatic)          46.0
# 5                        Police          22.0
# 6                        Police          25.0
# 7                     Utilities         107.0
# 8                      Military          28.0
# 9          Government (General)          21.0
# 10                     Military          27.0
# 11                     Military          28.0
# 12          Airports & Aircraft          42.0
# 13         Government (General)          21.0
# 14                     Business           7.0
#
#                                      targsubtype1_txt  \
# 0                                      Named Civilian
# 1   Diplomatic Personnel (outside of embassy, cons...
# 2                     Radio Journalist/Staff/Facility
# 3                                   Embassy/Consulate
# 4                                   Embassy/Consulate
# 5     Police Building (headquarters, station, school)
# 6                     Police Security Forces/Officers
# 7                                         Electricity
# 8                 Military Recruiting Station/Academy
# 9                 Government Building/Facility/Office
# 10      Military Barracks/Base/Headquarters/Checkpost
# 11                Military Recruiting Station/Academy
# 12                       Aircraft (not at an airport)
# 13                Government Building/Facility/Office
# 14                              Retail/Grocery/Bakery
#
#                                      corp1  \
# 0                                      NaN
# 1              Belgian Ambassador Daughter
# 2                         Voice of America
# 3                                      NaN
# 4                                      NaN
# 5                  Cairo Police Department
# 6                         Uruguayan Police
# 7           Pacific Gas & Electric Company
# 8                                 R.O.T.C.
# 9                        Selective Service
# 10                                     NaN
# 11                 Army Recruiting Station
# 12                     Trans World Airline
# 13                 U.S. Government housing
# 14  American owned business in Puerto Rico
#
#                                               target1  natlty1  \
# 0                                        Julio Guzman     58.0
# 1                             Nadine Chaval, daughter     21.0
# 2                                            Employee    217.0
# 3                                        U.S. Embassy    217.0
# 4                                      U.S. Consulate    217.0
# 5                           Cairo Police Headquarters    217.0
# 6   Juan Maria de Lucah/Chief of Directorate of in...    218.0
# 7                                     Edes Substation    217.0
# 8   R.O.T.C. offices at University of Wisconsin, M...    217.0
# 9   Selective Service Headquarters in Madison Wisc...    217.0
# 10                            Badger Army ammo depot.    217.0
# 11           Army Recruiting Station, Denver Colorado    217.0
# 12                              Flight 802 Boeing 707    217.0
# 13    Packard Properties building of Detroit Michigan    217.0
# 14                                      Baker's Store    217.0
#
#            natlty1_txt  targtype2 targtype2_txt  targsubtype2  \
# 0   Dominican Republic        NaN           NaN           NaN
# 1              Belgium        NaN           NaN           NaN
# 2        United States        NaN           NaN           NaN
# 3        United States        NaN           NaN           NaN
# 4        United States        NaN           NaN           NaN
# 5        United States        NaN           NaN           NaN
# 6              Uruguay        NaN           NaN           NaN
# 7        United States        NaN           NaN           NaN
# 8        United States        NaN           NaN           NaN
# 9        United States        NaN           NaN           NaN
# 10       United States        NaN           NaN           NaN
# 11       United States        NaN           NaN           NaN
# 12       United States        NaN           NaN           NaN
# 13       United States        NaN           NaN           NaN
# 14       United States        NaN           NaN           NaN
#
#    targsubtype2_txt corp2 target2  natlty2 natlty2_txt  targtype3  \
# 0               NaN   NaN     NaN      NaN         NaN        NaN
# 1               NaN   NaN     NaN      NaN         NaN        NaN
# 2               NaN   NaN     NaN      NaN         NaN        NaN
# 3               NaN   NaN     NaN      NaN         NaN        NaN
# 4               NaN   NaN     NaN      NaN         NaN        NaN
# 5               NaN   NaN     NaN      NaN         NaN        NaN
# 6               NaN   NaN     NaN      NaN         NaN        NaN
# 7               NaN   NaN     NaN      NaN         NaN        NaN
# 8               NaN   NaN     NaN      NaN         NaN        NaN
# 9               NaN   NaN     NaN      NaN         NaN        NaN
# 10              NaN   NaN     NaN      NaN         NaN        NaN
# 11              NaN   NaN     NaN      NaN         NaN        NaN
# 12              NaN   NaN     NaN      NaN         NaN        NaN
# 13              NaN   NaN     NaN      NaN         NaN        NaN
# 14              NaN   NaN     NaN      NaN         NaN        NaN
#
#    targtype3_txt  targsubtype3 targsubtype3_txt corp3 target3  natlty3  \
# 0            NaN           NaN              NaN   NaN     NaN      NaN
# 1            NaN           NaN              NaN   NaN     NaN      NaN
# 2            NaN           NaN              NaN   NaN     NaN      NaN
# 3            NaN           NaN              NaN   NaN     NaN      NaN
# 4            NaN           NaN              NaN   NaN     NaN      NaN
# 5            NaN           NaN              NaN   NaN     NaN      NaN
# 6            NaN           NaN              NaN   NaN     NaN      NaN
# 7            NaN           NaN              NaN   NaN     NaN      NaN
# 8            NaN           NaN              NaN   NaN     NaN      NaN
# 9            NaN           NaN              NaN   NaN     NaN      NaN
# 10           NaN           NaN              NaN   NaN     NaN      NaN
# 11           NaN           NaN              NaN   NaN     NaN      NaN
# 12           NaN           NaN              NaN   NaN     NaN      NaN
# 13           NaN           NaN              NaN   NaN     NaN      NaN
# 14           NaN           NaN              NaN   NaN     NaN      NaN
#
#    natlty3_txt                               gname gsubname gname2 gsubname2  \
# 0          NaN                              MANO-D      NaN    NaN       NaN
# 1          NaN  23rd of September Communist League      NaN    NaN       NaN
# 2          NaN                             Unknown      NaN    NaN       NaN
# 3          NaN                             Unknown      NaN    NaN       NaN
# 4          NaN                             Unknown      NaN    NaN       NaN
# 5          NaN                  Black Nationalists      NaN    NaN       NaN
# 6          NaN                 Tupamaros (Uruguay)      NaN    NaN       NaN
# 7          NaN                             Unknown      NaN    NaN       NaN
# 8          NaN                     New Year's Gang      NaN    NaN       NaN
# 9          NaN                     New Year's Gang      NaN    NaN       NaN
# 10         NaN     Weather Underground, Weathermen      NaN    NaN       NaN
# 11         NaN                 Left-Wing Militants      NaN    NaN       NaN
# 12         NaN                             Unknown      NaN    NaN       NaN
# 13         NaN                 Left-Wing Militants      NaN    NaN       NaN
# 14         NaN       Armed Commandos of Liberation      NaN    NaN       NaN
#
#    gname3 gsubname3                                             motive  \
# 0     NaN       NaN                                                NaN
# 1     NaN       NaN                                                NaN
# 2     NaN       NaN                                                NaN
# 3     NaN       NaN                                                NaN
# 4     NaN       NaN                                                NaN
# 5     NaN       NaN     To protest the Cairo Illinois Police Deparment
# 6     NaN       NaN                                                NaN
# 7     NaN       NaN                                                NaN
# 8     NaN       NaN        To protest the War in Vietnam and the draft
# 9     NaN       NaN        To protest the War in Vietnam and the draft
# 10    NaN       NaN                                                NaN
# 11    NaN       NaN                  Protest the draft and Vietnam War
# 12    NaN       NaN                                                NaN
# 13    NaN       NaN                                                NaN
# 14    NaN       NaN  To protest United States owned businesses in P...
#
#     guncertain1  guncertain2  guncertain3  individual  nperps  nperpcap  \
# 0           0.0          NaN          NaN           0     NaN       NaN
# 1           0.0          NaN          NaN           0     7.0       NaN
# 2           0.0          NaN          NaN           0     NaN       NaN
# 3           0.0          NaN          NaN           0     NaN       NaN
# 4           0.0          NaN          NaN           0     NaN       NaN
# 5           0.0          NaN          NaN           0   -99.0     -99.0
# 6           0.0          NaN          NaN           0     3.0       NaN
# 7           0.0          NaN          NaN           0   -99.0     -99.0
# 8           0.0          NaN          NaN           0     1.0       1.0
# 9           0.0          NaN          NaN           0     1.0       1.0
# 10          0.0          NaN          NaN           0     NaN       NaN
# 11          0.0          NaN          NaN           0   -99.0     -99.0
# 12          0.0          NaN          NaN           0     1.0       NaN
# 13          0.0          NaN          NaN           0   -99.0     -99.0
# 14          1.0          NaN          NaN           0   -99.0     -99.0
#
#     claimed  claimmode claimmode_txt  claim2  claimmode2 claimmode2_txt  \
# 0       NaN        NaN           NaN     NaN         NaN            NaN
# 1       NaN        NaN           NaN     NaN         NaN            NaN
# 2       NaN        NaN           NaN     NaN         NaN            NaN
# 3       NaN        NaN           NaN     NaN         NaN            NaN
# 4       NaN        NaN           NaN     NaN         NaN            NaN
# 5       0.0        NaN           NaN     NaN         NaN            NaN
# 6       NaN        NaN           NaN     NaN         NaN            NaN
# 7       0.0        NaN           NaN     NaN         NaN            NaN
# 8       1.0        1.0        Letter     NaN         NaN            NaN
# 9       0.0        NaN           NaN     NaN         NaN            NaN
# 10      NaN        NaN           NaN     NaN         NaN            NaN
# 11      0.0        NaN           NaN     NaN         NaN            NaN
# 12      NaN        NaN           NaN     NaN         NaN            NaN
# 13      0.0        NaN           NaN     NaN         NaN            NaN
# 14      1.0       10.0       Unknown     NaN         NaN            NaN
#
#     claim3  claimmode3 claimmode3_txt  compclaim  weaptype1 weaptype1_txt  \
# 0      NaN         NaN            NaN        NaN         13       Unknown
# 1      NaN         NaN            NaN        NaN         13       Unknown
# 2      NaN         NaN            NaN        NaN         13       Unknown
# 3      NaN         NaN            NaN        NaN          6    Explosives
# 4      NaN         NaN            NaN        NaN          8    Incendiary
# 5      NaN         NaN            NaN        NaN          5      Firearms
# 6      NaN         NaN            NaN        NaN          5      Firearms
# 7      NaN         NaN            NaN        NaN          6    Explosives
# 8      NaN         NaN            NaN        NaN          8    Incendiary
# 9      NaN         NaN            NaN        NaN          8    Incendiary
# 10     NaN         NaN            NaN        NaN          6    Explosives
# 11     NaN         NaN            NaN        NaN          8    Incendiary
# 12     NaN         NaN            NaN        NaN          5      Firearms
# 13     NaN         NaN            NaN        NaN          8    Incendiary
# 14     NaN         NaN            NaN        NaN          8    Incendiary
#
#     weapsubtype1                   weapsubtype1_txt  weaptype2 weaptype2_txt  \
# 0            NaN                                NaN        NaN           NaN
# 1            NaN                                NaN        NaN           NaN
# 2            NaN                                NaN        NaN           NaN
# 3           16.0             Unknown Explosive Type        NaN           NaN
# 4            NaN                                NaN        NaN           NaN
# 5            5.0                   Unknown Gun Type        NaN           NaN
# 6            2.0  Automatic or Semi-Automatic Rifle        NaN           NaN
# 7           16.0             Unknown Explosive Type        NaN           NaN
# 8           19.0       Molotov Cocktail/Petrol Bomb        NaN           NaN
# 9           20.0                Gasoline or Alcohol        NaN           NaN
# 10          16.0             Unknown Explosive Type        NaN           NaN
# 11          19.0       Molotov Cocktail/Petrol Bomb        NaN           NaN
# 12           4.0      Rifle/Shotgun (non-automatic)        5.0      Firearms
# 13          19.0       Molotov Cocktail/Petrol Bomb        NaN           NaN
# 14          18.0                         Arson/Fire        NaN           NaN
#
#     weapsubtype2 weapsubtype2_txt  weaptype3 weaptype3_txt  weapsubtype3  \
# 0            NaN              NaN        NaN           NaN           NaN
# 1            NaN              NaN        NaN           NaN           NaN
# 2            NaN              NaN        NaN           NaN           NaN
# 3            NaN              NaN        NaN           NaN           NaN
# 4            NaN              NaN        NaN           NaN           NaN
# 5            NaN              NaN        NaN           NaN           NaN
# 6            NaN              NaN        NaN           NaN           NaN
# 7            NaN              NaN        NaN           NaN           NaN
# 8            NaN              NaN        NaN           NaN           NaN
# 9            NaN              NaN        NaN           NaN           NaN
# 10           NaN              NaN        NaN           NaN           NaN
# 11           NaN              NaN        NaN           NaN           NaN
# 12           3.0          Handgun        NaN           NaN           NaN
# 13           NaN              NaN        NaN           NaN           NaN
# 14           NaN              NaN        NaN           NaN           NaN
#
#    weapsubtype3_txt  weaptype4 weaptype4_txt  weapsubtype4 weapsubtype4_txt  \
# 0               NaN        NaN           NaN           NaN              NaN
# 1               NaN        NaN           NaN           NaN              NaN
# 2               NaN        NaN           NaN           NaN              NaN
# 3               NaN        NaN           NaN           NaN              NaN
# 4               NaN        NaN           NaN           NaN              NaN
# 5               NaN        NaN           NaN           NaN              NaN
# 6               NaN        NaN           NaN           NaN              NaN
# 7               NaN        NaN           NaN           NaN              NaN
# 8               NaN        NaN           NaN           NaN              NaN
# 9               NaN        NaN           NaN           NaN              NaN
# 10              NaN        NaN           NaN           NaN              NaN
# 11              NaN        NaN           NaN           NaN              NaN
# 12              NaN        NaN           NaN           NaN              NaN
# 13              NaN        NaN           NaN           NaN              NaN
# 14              NaN        NaN           NaN           NaN              NaN
#
#                                            weapdetail  nkill  nkillus  \
# 0                                                 NaN    1.0      NaN
# 1                                                 NaN    0.0      NaN
# 2                                                 NaN    1.0      NaN
# 3                                           Explosive    NaN      NaN
# 4                                          Incendiary    NaN      NaN
# 5                        Several gunshots were fired.    0.0      0.0
# 6                                   Automatic firearm    0.0      NaN
# 7                                                 NaN    0.0      0.0
# 8                     Firebomb consisting of gasoline    0.0      0.0
# 9   Poured gasoline on the floor and lit it with a...    0.0      0.0
# 10                                          Explosive    0.0      NaN
# 11                                   Molotov cocktail    0.0      0.0
# 12                           Rifle - carbine; Pistols    0.0      0.0
# 13                                           Firebomb    0.0      0.0
# 14                          Fire set in back of store    0.0      0.0
#
#     nkillter  nwound  nwoundus  nwoundte  property  propextent  \
# 0        NaN     0.0       NaN       NaN         0         NaN
# 1        NaN     0.0       NaN       NaN         0         NaN
# 2        NaN     0.0       NaN       NaN         0         NaN
# 3        NaN     NaN       NaN       NaN         1         NaN
# 4        NaN     NaN       NaN       NaN         1         NaN
# 5        0.0     0.0       0.0       0.0         1         3.0
# 6        NaN     0.0       NaN       NaN         0         NaN
# 7        0.0     0.0       0.0       0.0         1         3.0
# 8        0.0     0.0       0.0       0.0         1         3.0
# 9        0.0     0.0       0.0       0.0         1         3.0
# 10       NaN     0.0       NaN       NaN         0         3.0
# 11       0.0     0.0       0.0       0.0         1         3.0
# 12       0.0     0.0       0.0       0.0         0         NaN
# 13       0.0     0.0       0.0       0.0         1         3.0
# 14       0.0     0.0       0.0       0.0         1         2.0
#
#                                    propextent_txt  propvalue  \
# 0                                             NaN        NaN
# 1                                             NaN        NaN
# 2                                             NaN        NaN
# 3                                             NaN        NaN
# 4                                             NaN        NaN
# 5                     Minor (likely < $1 million)        NaN
# 6                                             NaN        NaN
# 7                     Minor (likely < $1 million)    22500.0
# 8                     Minor (likely < $1 million)    60000.0
# 9                     Minor (likely < $1 million)        NaN
# 10                    Minor (likely < $1 million)        0.0
# 11                    Minor (likely < $1 million)      305.0
# 12                                            NaN        NaN
# 13                    Minor (likely < $1 million)        NaN
# 14  Major (likely >= $1 million but < $1 billion)  2000000.0
#
#                                           propcomment  ishostkid  nhostkid  \
# 0                                                 NaN        0.0       NaN
# 1                                                 NaN        1.0       1.0
# 2                                                 NaN        0.0       NaN
# 3                                                 NaN        0.0       NaN
# 4                                                 NaN        0.0       NaN
# 5                                                 NaN        0.0       NaN
# 6                                                 NaN        0.0       NaN
# 7                    Three transformers were damaged.        0.0       NaN
# 8   Basketball courts, weight room, swimming pool,...        0.0       NaN
# 9                                       Slight damage        0.0       NaN
# 10                                                NaN        0.0       NaN
# 11                                                NaN        0.0       NaN
# 12                                                NaN        0.0       NaN
# 13                               Building was damaged        0.0       NaN
# 14                                    Store destroyed        0.0       NaN
#
#     nhostkidus  nhours  ndays  divert kidhijcountry  ransom  ransomamt  \
# 0          NaN     NaN    NaN     NaN           NaN     0.0        NaN
# 1          0.0     NaN    NaN     NaN        Mexico     1.0   800000.0
# 2          NaN     NaN    NaN     NaN           NaN     0.0        NaN
# 3          NaN     NaN    NaN     NaN           NaN     0.0        NaN
# 4          NaN     NaN    NaN     NaN           NaN     0.0        NaN
# 5          NaN     NaN    NaN     NaN           NaN     0.0        NaN
# 6          NaN     NaN    NaN     NaN           NaN     0.0        NaN
# 7          NaN     NaN    NaN     NaN           NaN     0.0        NaN
# 8          NaN     NaN    NaN     NaN           NaN     0.0        NaN
# 9          NaN     NaN    NaN     NaN           NaN     0.0        NaN
# 10         NaN     NaN    NaN     NaN           NaN     0.0        NaN
# 11         NaN     NaN    NaN     NaN           NaN     0.0        NaN
# 12         NaN     NaN    NaN  Beirut        Beirut     0.0        NaN
# 13         NaN     NaN    NaN     NaN           NaN     0.0        NaN
# 14         NaN     NaN    NaN     NaN           NaN     0.0        NaN
#
#     ransomamtus  ransompaid  ransompaidus ransomnote  hostkidoutcome  \
# 0           NaN         NaN           NaN        NaN             NaN
# 1           NaN         NaN           NaN        NaN             NaN
# 2           NaN         NaN           NaN        NaN             NaN
# 3           NaN         NaN           NaN        NaN             NaN
# 4           NaN         NaN           NaN        NaN             NaN
# 5           NaN         NaN           NaN        NaN             NaN
# 6           NaN         NaN           NaN        NaN             NaN
# 7           NaN         NaN           NaN        NaN             NaN
# 8           NaN         NaN           NaN        NaN             NaN
# 9           NaN         NaN           NaN        NaN             NaN
# 10          NaN         NaN           NaN        NaN             NaN
# 11          NaN         NaN           NaN        NaN             NaN
# 12          NaN         NaN           NaN        NaN             2.0
# 13          NaN         NaN           NaN        NaN             NaN
# 14          NaN         NaN           NaN        NaN             NaN
#
#                      hostkidoutcome_txt  nreleased  \
# 0                                   NaN        NaN
# 1                                   NaN        NaN
# 2                                   NaN        NaN
# 3                                   NaN        NaN
# 4                                   NaN        NaN
# 5                                   NaN        NaN
# 6                                   NaN        NaN
# 7                                   NaN        NaN
# 8                                   NaN        NaN
# 9                                   NaN        NaN
# 10                                  NaN        NaN
# 11                                  NaN        NaN
# 12  Hostage(s) released by perpetrators        NaN
# 13                                  NaN        NaN
# 14                                  NaN        NaN
#
#                                              addnotes  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5   The Cairo Chief of Police, William Petersen, r...
# 6                                                 NaN
# 7   Damages were estimated to be between $20,000-$...
# 8   The New Years Gang issue a communiqu� to a loc...
# 9   Karl Armstrong's girlfriend, Lynn Schultz, dro...
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  The fire began at 8:30 PM. The Armed Commandos...
#
#                                                scite1  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5   "Police Chief Quits," Washington Post, January...
# 6                                                 NaN
# 7   Committee on Government Operations United Stat...
# 8   Tom Bates, "Rads: The 1970 Bombing of the Army...
# 9   Committee on Government Operations United Stat...
# 10                                                NaN
# 11  Committee on Government Operations United Stat...
# 12                                                NaN
# 13  Committee on Government Operations United Stat...
# 14  Committee on the Judiciary  United States Sena...
#
#                                                scite2  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5   "Cairo Police Chief Quits; Decries Local 'Mili...
# 6                                                 NaN
# 7   Christopher Hewitt, "Political Violence and Te...
# 8   David Newman, Sandra Sutherland, and Jon Stewa...
# 9   Tom Bates, "Rads: The 1970 Bombing of the Army...
# 10                                                NaN
# 11  Christopher Hewitt, "Political Violence and Te...
# 12                                                NaN
# 13  Christopher Hewitt, "Political Violence and Te...
# 14  "No Evidence Of Arson Found In Barkers Fire," ...
#
#                                                scite3        dbsource  \
# 0                                                 NaN            PGIS
# 1                                                 NaN            PGIS
# 2                                                 NaN            PGIS
# 3                                                 NaN            PGIS
# 4                                                 NaN            PGIS
# 5   Christopher Hewitt, "Political Violence and Te...  Hewitt Project
# 6                                                 NaN            PGIS
# 7                                                 NaN  Hewitt Project
# 8   The Wisconsin Cartographers' Guild, "Wisconsin...  Hewitt Project
# 9   David Newman, Sandra Sutherland, and Jon Stewa...  Hewitt Project
# 10                                                NaN            PGIS
# 11                                                NaN  Hewitt Project
# 12                                                NaN    Hijacking DB
# 13                                                NaN  Hewitt Project
# 14  "Toward People's War for Independence and Soci...  Hewitt Project
#
#     INT_LOG  INT_IDEO  INT_MISC  INT_ANY related
# 0         0         0         0        0     NaN
# 1         0         1         1        1     NaN
# 2        -9        -9         1        1     NaN
# 3        -9        -9         1        1     NaN
# 4        -9        -9         1        1     NaN
# 5        -9        -9         0       -9     NaN
# 6         0         0         0        0     NaN
# 7        -9        -9         0       -9     NaN
# 8         0         0         0        0     NaN
# 9         0         0         0        0     NaN
# 10        0         0         0        0     NaN
# 11       -9        -9         0       -9     NaN
# 12       -9        -9         1        1     NaN
# 13       -9        -9         0       -9     NaN
# 14        0         0         0        0     NaN

# %% [markdown]
# ## Data Exploration

# %%
#checking column headers
gt.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %% [markdown]
# Not displaying all column headers as expected

# %%
gt.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# 25%         0.000000      78.000000       5.000000      11.510046
# 50%         0.000000      98.000000       6.000000      31.467463
# 75%         0.000000     160.000000      10.000000      34.685087
# max         1.000000    1004.000000      12.000000      74.633553
#
#           longitude    specificity       vicinity          crit1  \
# count  1.771340e+05  181685.000000  181691.000000  181691.000000
# mean  -4.586957e+02       1.451452       0.068297       0.988530
# std    2.047790e+05       0.995430       0.284553       0.106483
# min   -8.618590e+07       1.000000      -9.000000       0.000000
# 25%    4.545640e+00       1.000000       0.000000       1.000000
# 50%    4.324651e+01       1.000000       0.000000       1.000000
# 75%    6.871033e+01       1.000000       0.000000       1.000000
# max    1.793667e+02       5.000000       1.000000       1.000000
#
#                crit2          crit3      doubtterr   alternative  \
# count  181691.000000  181691.000000  181690.000000  29011.000000
# mean        0.993093       0.875668      -0.523171      1.292923
# std         0.082823       0.329961       2.455819      0.703729
# min         0.000000       0.000000      -9.000000      1.000000
# 25%         1.000000       1.000000       0.000000      1.000000
# 50%         1.000000       1.000000       0.000000      1.000000
# 75%         1.000000       1.000000       0.000000      1.000000
# max         1.000000       1.000000       1.000000      5.000000
#
#             multiple        success        suicide    attacktype1  \
# count  181690.000000  181691.000000  181691.000000  181691.000000
# mean        0.137773       0.889598       0.036507       3.247547
# std         0.344663       0.313391       0.187549       1.915772
# min         0.000000       0.000000       0.000000       1.000000
# 25%         0.000000       1.000000       0.000000       2.000000
# 50%         0.000000       1.000000       0.000000       3.000000
# 75%         0.000000       1.000000       0.000000       3.000000
# max         1.000000       1.000000       1.000000       9.000000
#
#        attacktype2  attacktype3      targtype1   targsubtype1        natlty1  \
# count  6314.000000   428.000000  181691.000000  171318.000000  180132.000000
# mean      3.719512     5.245327       8.439719      46.971474     127.686441
# std       2.272023     2.246642       6.653838      30.953357      89.299120
# min       1.000000     1.000000       1.000000       1.000000       4.000000
# 25%       2.000000     2.000000       3.000000      22.000000      83.000000
# 50%       2.000000     7.000000       4.000000      35.000000     101.000000
# 75%       7.000000     7.000000      14.000000      74.000000     173.000000
# max       9.000000     8.000000      22.000000     113.000000    1004.000000
#
#           targtype2  targsubtype2       natlty2    targtype3  targsubtype3  \
# count  11144.000000  10685.000000  10828.000000  1176.000000   1097.000000
# mean      10.247218     55.311652    131.179442    10.021259     55.548769
# std        5.709076     25.640310    125.951485     5.723447     26.288955
# min        1.000000      1.000000      4.000000     1.000000      1.000000
# 25%        4.000000     34.000000     92.000000     3.000000     33.000000
# 50%       14.000000     67.000000     98.000000    14.000000     67.000000
# 75%       14.000000     69.000000    182.000000    14.000000     73.000000
# max       22.000000    113.000000   1004.000000    22.000000    113.000000
#
#            natlty3    guncertain1  guncertain2  guncertain3     individual  \
# count  1147.000000  181311.000000  1955.000000   320.000000  181691.000000
# mean    144.564952       0.081440     0.265473     0.193750       0.002950
# std     163.299295       0.273511     0.441698     0.395854       0.054234
# min       4.000000       0.000000     0.000000     0.000000       0.000000
# 25%      75.000000       0.000000     0.000000     0.000000       0.000000
# 50%     110.000000       0.000000     0.000000     0.000000       0.000000
# 75%     182.000000       0.000000     1.000000     0.000000       0.000000
# max    1004.000000       1.000000     1.000000     1.000000       1.000000
#
#               nperps       nperpcap        claimed     claimmode       claim2  \
# count  110576.000000  112202.000000  115571.000000  19083.000000  1890.000000
# mean      -65.361154      -1.517727       0.049666      7.022848     0.247619
# std       216.536633      12.830346       1.093195      2.476851     0.974018
# min       -99.000000     -99.000000      -9.000000      1.000000    -9.000000
# 25%       -99.000000       0.000000       0.000000      6.000000     0.000000
# 50%       -99.000000       0.000000       0.000000      8.000000     0.000000
# 75%         1.000000       0.000000       0.000000      8.000000     1.000000
# max     25000.000000     406.000000       1.000000     10.000000     1.000000
#
#        claimmode2      claim3  claimmode3    compclaim      weaptype1  \
# count  616.000000  318.000000  133.000000  4839.000000  181691.000000
# mean     7.176948    0.411950    6.729323    -6.296342       6.447325
# std      2.783725    0.492962    2.908003     4.234620       2.173435
# min      1.000000    0.000000    1.000000    -9.000000       1.000000
# 25%      6.000000    0.000000    4.000000    -9.000000       5.000000
# 50%      7.000000    0.000000    7.000000    -9.000000       6.000000
# 75%     10.000000    1.000000    9.000000     0.000000       6.000000
# max     10.000000    1.000000   10.000000     1.000000      13.000000
#
#         weapsubtype1     weaptype2  weapsubtype2    weaptype3  weapsubtype3  \
# count  160923.000000  13127.000000  11542.000000  1863.000000   1693.000000
# mean       11.117162      6.812524     10.754029     6.911433     11.643237
# std         6.495612      2.277081      7.594574     2.177956      8.493166
# min         1.000000      1.000000      1.000000     2.000000      1.000000
# 25%         5.000000      5.000000      5.000000     5.000000      4.000000
# 50%        12.000000      6.000000      7.000000     6.000000      7.000000
# 75%        16.000000      8.000000     18.000000     9.000000     20.000000
# max        31.000000     13.000000     31.000000    13.000000     28.000000
#
#        weaptype4  weapsubtype4          nkill        nkillus       nkillter  \
# count  73.000000     70.000000  171378.000000  117245.000000  114733.000000
# mean    6.246575     10.842857       2.403272       0.045981       0.508058
# std     1.507212      8.192672      11.545741       5.681854       4.199937
# min     5.000000      2.000000       0.000000       0.000000       0.000000
# 25%     5.000000      3.000000       0.000000       0.000000       0.000000
# 50%     6.000000      9.500000       0.000000       0.000000       0.000000
# 75%     6.000000     16.000000       2.000000       0.000000       0.000000
# max    12.000000     28.000000    1570.000000    1360.000000     500.000000
#
#               nwound       nwoundus       nwoundte       property  \
# count  165380.000000  116989.000000  112548.000000  181691.000000
# mean        3.167668       0.038944       0.107163      -0.544556
# std        35.949392       3.057361       1.488881       3.122889
# min         0.000000       0.000000       0.000000      -9.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       1.000000
# 75%         2.000000       0.000000       0.000000       1.000000
# max      8191.000000     751.000000     200.000000       1.000000
#
#          propextent     propvalue      ishostkid      nhostkid    nhostkidus  \
# count  64065.000000  3.898900e+04  181513.000000  13572.000000  13517.000000
# mean       3.295403  2.088119e+05       0.059054      4.533230     -0.353999
# std        0.486912  1.552463e+07       0.461244    202.316386      6.835645
# min        1.000000 -9.900000e+01      -9.000000    -99.000000    -99.000000
# 25%        3.000000 -9.900000e+01       0.000000      1.000000      0.000000
# 50%        3.000000 -9.900000e+01       0.000000      2.000000      0.000000
# 75%        4.000000  1.000000e+03       0.000000      4.000000      0.000000
# max        4.000000  2.700000e+09       1.000000  17000.000000     86.000000
#
#             nhours        ndays        ransom     ransomamt   ransomamtus  \
# count  4063.000000  8124.000000  77381.000000  1.350000e+03  5.630000e+02
# mean    -46.793933   -32.516371     -0.145811  3.172530e+06  5.784865e+05
# std      82.800405   121.209205      1.207861  3.021157e+07  7.077924e+06
# min     -99.000000   -99.000000     -9.000000 -9.900000e+01 -9.900000e+01
# 25%     -99.000000   -99.000000      0.000000  0.000000e+00  0.000000e+00
# 50%     -99.000000   -99.000000      0.000000  1.500000e+04  0.000000e+00
# 75%       0.000000     4.000000      0.000000  4.000000e+05  0.000000e+00
# max     999.000000  2454.000000      1.000000  1.000000e+09  1.320000e+08
#
#          ransompaid  ransompaidus  hostkidoutcome     nreleased  \
# count  7.740000e+02    552.000000    10991.000000  10400.000000
# mean   7.179437e+05    240.378623        4.629242    -29.018269
# std    1.014392e+07   2940.967293        2.035360     65.720119
# min   -9.900000e+01    -99.000000        1.000000    -99.000000
# 25%   -9.900000e+01      0.000000        2.000000    -99.000000
# 50%    0.000000e+00      0.000000        4.000000      0.000000
# 75%    1.273412e+03      0.000000        7.000000      1.000000
# max    2.750000e+08  48000.000000        7.000000   2769.000000
#
#              INT_LOG       INT_IDEO       INT_MISC        INT_ANY
# count  181691.000000  181691.000000  181691.000000  181691.000000
# mean       -4.543731      -4.464398       0.090010      -3.945952
# std         4.543547       4.637152       0.568457       4.691325
# min        -9.000000      -9.000000      -9.000000      -9.000000
# 25%        -9.000000      -9.000000       0.000000      -9.000000
# 50%        -9.000000      -9.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000       1.000000

# %%
gt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %% [markdown]
# Not helpful for decision-making or datatype of relevant columns

# %%
#get a fuller view of the column names
list(gt.columns)
# Out:
# ['eventid',
#  'iyear',
#  'imonth',
#  'iday',
#  'approxdate',
#  'extended',
#  'resolution',
#  'country',
#  'country_txt',
#  'region',
#  'region_txt',
#  'provstate',
#  'city',
#  'latitude',
#  'longitude',
#  'specificity',
#  'vicinity',
#  'location',
#  'summary',
#  'crit1',
#  'crit2',
#  'crit3',
#  'doubtterr',
#  'alternative',
#  'alternative_txt',
#  'multiple',
#  'success',
#  'suicide',
#  'attacktype1',
#  'attacktype1_txt',
#  'attacktype2',
#  'attacktype2_txt',
#  'attacktype3',
#  'attacktype3_txt',
#  'targtype1',
#  'targtype1_txt',
#  'targsubtype1',
#  'targsubtype1_txt',
#  'corp1',
#  'target1',
#  'natlty1',
#  'natlty1_txt',
#  'targtype2',
#  'targtype2_txt',
#  'targsubtype2',
#  'targsubtype2_txt',
#  'corp2',
#  'target2',
#  'natlty2',
#  'natlty2_txt',
#  'targtype3',
#  'targtype3_txt',
#  'targsubtype3',
#  'targsubtype3_txt',
#  'corp3',
#  'target3',
#  'natlty3',
#  'natlty3_txt',
#  'gname',
#  'gsubname',
#  'gname2',
#  'gsubname2',
#  'gname3',
#  'gsubname3',
#  'motive',
#  'guncertain1',
#  'guncertain2',
#  'guncertain3',
#  'individual',
#  'nperps',
#  'nperpcap',
#  'claimed',
#  'claimmode',
#  'claimmode_txt',
#  'claim2',
#  'claimmode2',
#  'claimmode2_txt',
#  'claim3',
#  'claimmode3',
#  'claimmode3_txt',
#  'compclaim',
#  'weaptype1',
#  'weaptype1_txt',
#  'weapsubtype1',
#  'weapsubtype1_txt',
#  'weaptype2',
#  'weaptype2_txt',
#  'weapsubtype2',
#  'weapsubtype2_txt',
#  'weaptype3',
#  'weaptype3_txt',
#  'weapsubtype3',
#  'weapsubtype3_txt',
#  'weaptype4',
#  'weaptype4_txt',
#  'weapsubtype4',
#  'weapsubtype4_txt',
#  'weapdetail',
#  'nkill',
#  'nkillus',
#  'nkillter',
#  'nwound',
#  'nwoundus',
#  'nwoundte',
#  'property',
#  'propextent',
#  'propextent_txt',
#  'propvalue',
#  'propcomment',
#  'ishostkid',
#  'nhostkid',
#  'nhostkidus',
#  'nhours',
#  'ndays',
#  'divert',
#  'kidhijcountry',
#  'ransom',
#  'ransomamt',
#  'ransomamtus',
#  'ransompaid',
#  'ransompaidus',
#  'ransomnote',
#  'hostkidoutcome',
#  'hostkidoutcome_txt',
#  'nreleased',
#  'addnotes',
#  'scite1',
#  'scite2',
#  'scite3',
#  'dbsource',
#  'INT_LOG',
#  'INT_IDEO',
#  'INT_MISC',
#  'INT_ANY',
#  'related']

# %%
#checking the number of rows and columns
gt.shape
# Out:
# (181691, 135)

# %%
#checking for unique values in the dataset
gt.nunique()
# Out:
# eventid               181691
# iyear                     47
# imonth                    13
# iday                      32
# approxdate              2244
# extended                   2
# resolution              1859
# country                  205
# country_txt              205
# region                    12
# region_txt                12
# provstate               2854
# city                   36674
# latitude               48322
# longitude              48039
# specificity                5
# vicinity                   3
# location               44109
# summary               112492
# crit1                      2
# crit2                      2
# crit3                      2
# doubtterr                  3
# alternative                5
# alternative_txt            5
# multiple                   2
# success                    2
# suicide                    2
# attacktype1                9
# attacktype1_txt            9
# attacktype2                9
# attacktype2_txt            9
# attacktype3                8
# attacktype3_txt            8
# targtype1                 22
# targtype1_txt             22
# targsubtype1             112
# targsubtype1_txt         112
# corp1                  33238
# target1                86006
# natlty1                  215
# natlty1_txt              215
# targtype2                 22
# targtype2_txt             22
# targsubtype2             107
# targsubtype2_txt         107
# corp2                   2691
# target2                 5043
# natlty2                  158
# natlty2_txt              158
# targtype3                 20
# targtype3_txt             20
# targsubtype3              92
# targsubtype3_txt          92
# corp3                    422
# target3                  720
# natlty3                  110
# natlty3_txt              110
# gname                   3537
# gsubname                1183
# gname2                   433
# gsubname2                 60
# gname3                   116
# gsubname3                 14
# motive                 14490
# guncertain1                2
# guncertain2                2
# guncertain3                2
# individual                 2
# nperps                   113
# nperpcap                  50
# claimed                    3
# claimmode                 10
# claimmode_txt             10
# claim2                     3
# claimmode2                 9
# claimmode2_txt             9
# claim3                     2
# claimmode3                 8
# claimmode3_txt             8
# compclaim                  3
# weaptype1                 12
# weaptype1_txt             12
# weapsubtype1              30
# weapsubtype1_txt          30
# weaptype2                 11
# weaptype2_txt             11
# weapsubtype2              28
# weapsubtype2_txt          28
# weaptype3                 10
# weaptype3_txt             10
# weapsubtype3              22
# weapsubtype3_txt          22
# weaptype4                  5
# weaptype4_txt              5
# weapsubtype4              16
# weapsubtype4_txt          16
# weapdetail             19148
# nkill                    205
# nkillus                   31
# nkillter                  96
# nwound                   238
# nwoundus                  44
# nwoundte                  44
# property                   3
# propextent                 4
# propextent_txt             4
# propvalue                659
# propcomment            19157
# ishostkid                  3
# nhostkid                 209
# nhostkidus                27
# nhours                    35
# ndays                    328
# divert                   143
# kidhijcountry            217
# ransom                     3
# ransomamt                429
# ransomamtus               23
# ransompaid               156
# ransompaidus               8
# ransomnote               387
# hostkidoutcome             7
# hostkidoutcome_txt         7
# nreleased                156
# addnotes               15429
# scite1                 83988
# scite2                 62263
# scite3                 36090
# dbsource                  26
# INT_LOG                    3
# INT_IDEO                   3
# INT_MISC                   3
# INT_ANY                    3
# related                14306
# dtype: int64

# %% [markdown]
# The data cuts across terrorism in 205 countries for 47 years, starting from 1970.
#
# Not all columns are relevant to the analysis, so reading the description on kaggle (https://www.kaggle.com/datasets/START-UMD/gtd) gives an insight into necessary columns.

# %%
#creating new dataset with selected columns based on column description from kaggle and intended problem statement
gt1 = gt[['iyear', 'imonth', 'iday', 'extended', 'country_txt', 'region_txt', 'city', 'success', 'suicide', 
        'attacktype1_txt', 'targtype1_txt', 'targsubtype1_txt', 'target1', 'natlty1_txt', 'gname', 'motive', 
        'nperps', 'weaptype1_txt', 'weapsubtype1_txt', 'nkill', 'nwound', 'property']]
gt1.head(10)
# Out:
#    iyear  imonth  iday  extended         country_txt  \
# 0   1970       7     2         0  Dominican Republic
# 1   1970       0     0         0              Mexico
# 2   1970       1     0         0         Philippines
# 3   1970       1     0         0              Greece
# 4   1970       1     0         0               Japan
# 5   1970       1     1         0       United States
# 6   1970       1     2         0             Uruguay
# 7   1970       1     2         0       United States
# 8   1970       1     2         0       United States
# 9   1970       1     3         0       United States
#
#                     region_txt           city  success  suicide  \
# 0  Central America & Caribbean  Santo Domingo        1        0
# 1                North America    Mexico city        1        0
# 2               Southeast Asia        Unknown        1        0
# 3               Western Europe         Athens        1        0
# 4                    East Asia        Fukouka        1        0
# 5                North America          Cairo        1        0
# 6                South America     Montevideo        0        0
# 7                North America        Oakland        1        0
# 8                North America        Madison        1        0
# 9                North America        Madison        1        0
#
#                   attacktype1_txt                targtype1_txt  \
# 0                   Assassination  Private Citizens & Property
# 1     Hostage Taking (Kidnapping)      Government (Diplomatic)
# 2                   Assassination          Journalists & Media
# 3               Bombing/Explosion      Government (Diplomatic)
# 4  Facility/Infrastructure Attack      Government (Diplomatic)
# 5                   Armed Assault                       Police
# 6                   Assassination                       Police
# 7               Bombing/Explosion                    Utilities
# 8  Facility/Infrastructure Attack                     Military
# 9  Facility/Infrastructure Attack         Government (General)
#
#                                     targsubtype1_txt  \
# 0                                     Named Civilian
# 1  Diplomatic Personnel (outside of embassy, cons...
# 2                    Radio Journalist/Staff/Facility
# 3                                  Embassy/Consulate
# 4                                  Embassy/Consulate
# 5    Police Building (headquarters, station, school)
# 6                    Police Security Forces/Officers
# 7                                        Electricity
# 8                Military Recruiting Station/Academy
# 9                Government Building/Facility/Office
#
#                                              target1         natlty1_txt  \
# 0                                       Julio Guzman  Dominican Republic
# 1                            Nadine Chaval, daughter             Belgium
# 2                                           Employee       United States
# 3                                       U.S. Embassy       United States
# 4                                     U.S. Consulate       United States
# 5                          Cairo Police Headquarters       United States
# 6  Juan Maria de Lucah/Chief of Directorate of in...             Uruguay
# 7                                    Edes Substation       United States
# 8  R.O.T.C. offices at University of Wisconsin, M...       United States
# 9  Selective Service Headquarters in Madison Wisc...       United States
#
#                                 gname  \
# 0                              MANO-D
# 1  23rd of September Communist League
# 2                             Unknown
# 3                             Unknown
# 4                             Unknown
# 5                  Black Nationalists
# 6                 Tupamaros (Uruguay)
# 7                             Unknown
# 8                     New Year's Gang
# 9                     New Year's Gang
#
#                                            motive  nperps weaptype1_txt  \
# 0                                             NaN     NaN       Unknown
# 1                                             NaN     7.0       Unknown
# 2                                             NaN     NaN       Unknown
# 3                                             NaN     NaN    Explosives
# 4                                             NaN     NaN    Incendiary
# 5  To protest the Cairo Illinois Police Deparment   -99.0      Firearms
# 6                                             NaN     3.0      Firearms
# 7                                             NaN   -99.0    Explosives
# 8     To protest the War in Vietnam and the draft     1.0    Incendiary
# 9     To protest the War in Vietnam and the draft     1.0    Incendiary
#
#                     weapsubtype1_txt  nkill  nwound  property
# 0                                NaN    1.0     0.0         0
# 1                                NaN    0.0     0.0         0
# 2                                NaN    1.0     0.0         0
# 3             Unknown Explosive Type    NaN     NaN         1
# 4                                NaN    NaN     NaN         1
# 5                   Unknown Gun Type    0.0     0.0         1
# 6  Automatic or Semi-Automatic Rifle    0.0     0.0         0
# 7             Unknown Explosive Type    0.0     0.0         1
# 8       Molotov Cocktail/Petrol Bomb    0.0     0.0         1
# 9                Gasoline or Alcohol    0.0     0.0         1

# %%
#understanding the new dataset
gt1.shape
# Out:
# (181691, 22)

# %%
#insights into missing values
gt1.isnull().sum()
# Out:
# iyear                    0
# imonth                   0
# iday                     0
# extended                 0
# country_txt              0
# region_txt               0
# city                   434
# success                  0
# suicide                  0
# attacktype1_txt          0
# targtype1_txt            0
# targsubtype1_txt     10373
# target1                636
# natlty1_txt           1559
# gname                    0
# motive              131130
# nperps               71115
# weaptype1_txt            0
# weapsubtype1_txt     20768
# nkill                10313
# nwound               16311
# property                 0
# dtype: int64

# %%
#null values in percentage per column
gt1.isnull().mean() * 100
# Out:
# iyear                0.000000
# imonth               0.000000
# iday                 0.000000
# extended             0.000000
# country_txt          0.000000
# region_txt           0.000000
# city                 0.238867
# success              0.000000
# suicide              0.000000
# attacktype1_txt      0.000000
# targtype1_txt        0.000000
# targsubtype1_txt     5.709144
# target1              0.350045
# natlty1_txt          0.858050
# gname                0.000000
# motive              72.171984
# nperps              39.140629
# weaptype1_txt        0.000000
# weapsubtype1_txt    11.430396
# nkill                5.676120
# nwound               8.977330
# property             0.000000
# dtype: float64

# %%
#dropping columns with null value percent > 10
gt1 = gt1.drop(['motive', 'nperps', 'weapsubtype1_txt'], axis=1)
gt1.shape
# Out:
# (181691, 19)

# %%
#renaming columns for easy access
gt1.columns = ['Year', 'Month', 'Day', 'Extended', 'Country', 
                   'Region', 'City', 'Success', 'Suicide', 'Attack_Type', 
                   'Target_Type', 'Target_Subtype', 'Target', 'Target_Nationality', 
                   'Attack_Group', 'Weapon', 'No_Of_Killed', 'No_Of_Wounded', 'Property']

# %%
#checking datatypes
gt1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 19 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Year                181691 non-null  int64
#  1   Month               181691 non-null  int64
#  2   Day                 181691 non-null  int64
#  3   Extended            181691 non-null  int64
#  4   Country             181691 non-null  object
#  5   Region              181691 non-null  object
#  6   City                181257 non-null  object
#  7   Success             181691 non-null  int64
#  8   Suicide             181691 non-null  int64
#  9   Attack_Type         181691 non-null  object
#  10  Target_Type         181691 non-null  object
#  11  Target_Subtype      171318 non-null  object
#  12  Target              181055 non-null  object
#  13  Target_Nationality  180132 non-null  object
#  14  Attack_Group        181691 non-null  object
#  15  Weapon              181691 non-null  object
#  16  No_Of_Killed        171378 non-null  float64
#  17  No_Of_Wounded       165380 non-null  float64
#  18  Property            181691 non-null  int64
# dtypes: float64(2), int64(7), object(10)
# memory usage: 26.3+ MB

# %% [markdown]
# Most columns appear to have the right format. Columns: success, suicide, and extended should be logicals (boolean). Then, dates should have the right formats.

# %%
#Check Missing Values
def check_missing(data):
    total = data.isnull().sum().sort_values(ascending=False)
    percent = (data.isnull().sum()/data.isnull().count()).sort_values(ascending=False)
    missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
    return missing_data.head(20)

check_missing(gt1)
# Out:
#                     Total   Percent
# No_Of_Wounded       16311  0.089773
# Target_Subtype      10373  0.057091
# No_Of_Killed        10313  0.056761
# Target_Nationality   1559  0.008581
# Target                636  0.003500
# City                  434  0.002389
# Year                    0  0.000000
# Target_Type             0  0.000000
# Weapon                  0  0.000000
# Attack_Group            0  0.000000
# Attack_Type             0  0.000000
# Month                   0  0.000000
# Suicide                 0  0.000000
# Success                 0  0.000000
# Region                  0  0.000000
# Country                 0  0.000000
# Extended                0  0.000000
# Day                     0  0.000000
# Property                0  0.000000

# %%
#filling missing values
gt1["Target"].fillna("Unknown", inplace = True)
gt1["Target_Subtype"].fillna("Unknown", inplace = True)
gt1["City"].fillna("Unknown", inplace = True) 
gt1["No_Of_Killed"].fillna(0, inplace = True)
gt1["Target_Nationality"].fillna("Unknown", inplace=True)
gt1["No_Of_Wounded"].fillna(0, inplace=True)

# %%
gt1.isnull().sum()
# Out:
# Year                  0
# Month                 0
# Day                   0
# Extended              0
# Country               0
# Region                0
# City                  0
# Success               0
# Suicide               0
# Attack_Type           0
# Target_Type           0
# Target_Subtype        0
# Target                0
# Target_Nationality    0
# Attack_Group          0
# Weapon                0
# No_Of_Killed          0
# No_Of_Wounded         0
# Property              0
# dtype: int64

# %%
#saving cleaned data to a new csv file
#gt1.to_csv('CleanedGlobalTerrorism.csv', index=False)

# %%
def check_duplicate(data):
    duplicate = data.duplicated()
    unique_data  = pd.Series(data.shape[0] - duplicate.value_counts()[1])
    duplicate_data = pd.Series(data.shape[0] - duplicate.value_counts()[0])
    unique_data_percent = pd.Series((unique_data/data.shape[0])*100)
    duplicate_data_percent = pd.Series((duplicate_data/data.shape[0])*100)
    dublicate = pd.concat([unique_data, duplicate_data,unique_data_percent,duplicate_data_percent], axis=1, keys=['Unique Count', 'Duplicate Count','Unique percent','Duplicate Percent'])
    return dublicate

check_duplicate(gt1)
# Out:
#    Unique Count  Duplicate Count  Unique percent  Duplicate Percent
# 0        170881            10810       94.050338           5.949662

# %%
# not behaving as expected, so nope...
#gt1 = gt1.drop_duplicates(inplace=True, keep=False)

# %%
#changing datatype from int to boolean
#column_names = ['Success', 'Suicide', 'Extended']
#gt1[column_names] = gt1[column_names].astype(bool)

# %%
gt1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 19 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Year                181691 non-null  int64
#  1   Month               181691 non-null  int64
#  2   Day                 181691 non-null  int64
#  3   Extended            181691 non-null  int64
#  4   Country             181691 non-null  object
#  5   Region              181691 non-null  object
#  6   City                181691 non-null  object
#  7   Success             181691 non-null  int64
#  8   Suicide             181691 non-null  int64
#  9   Attack_Type         181691 non-null  object
#  10  Target_Type         181691 non-null  object
#  11  Target_Subtype      181691 non-null  object
#  12  Target              181691 non-null  object
#  13  Target_Nationality  181691 non-null  object
#  14  Attack_Group        181691 non-null  object
#  15  Weapon              181691 non-null  object
#  16  No_Of_Killed        181691 non-null  float64
#  17  No_Of_Wounded       181691 non-null  float64
#  18  Property            181691 non-null  int64
# dtypes: float64(2), int64(7), object(10)
# memory usage: 26.3+ MB

# %% [markdown]
# ## Visualizations

# %%
#Identifying the year with the highest attack
plt.figure(figsize=(18,16))
plt.xticks(rotation= 90)
plot1 = sns.countplot(x= gt1['Year'].sort_values(), data= gt1)
plt.show()

# %% [markdown]
# 2014 has the highest terrorist attacks through all 47 countries and 1971 had the least.

# %%
#Identifying the country with the highest attck using countplot
plt.figure(figsize=(18,16))
plt.xticks(rotation= 90)
plot1 = sns.countplot(x= 'Country', data= gt1)
plt.show()

# %% [markdown]
# Too many countries (205) to consider. Countplot is a bad visual for it.

# %%
#Another approach to the country count
country = pd.DataFrame(gt1.groupby('Country')['Country'].size().sort_values(ascending=False))
country.columns = ['Count']
country_df = country.head(20)
country_df
# Out:
#                 Count
# Country
# Iraq            24636
# Pakistan        14368
# Afghanistan     12731
# India           11960
# Colombia         8306
# Philippines      6908
# Peru             6096
# El Salvador      5320
# United Kingdom   5235
# Turkey           4292
# Somalia          4142
# Nigeria          3907
# Thailand         3849
# Yemen            3347
# Spain            3249
# Sri Lanka        3022
# United States    2836
# Algeria          2743
# France           2693
# Egypt            2479

# %%
#plotting the top 20 countries with the highest terrorism
plt.figure(figsize=(14,6))
plt.xticks(rotation= 90)
plot1 = sns.barplot(x= country_df.index, y = 'Count', data= country_df)
plt.show()

# %% [markdown]
# * The top 20 countries with high global terrorism. Iraq, Pakistan and Afghanistan are leading on that.

# %%
#Checking the region with the highest terrorism
plt.figure(figsize=(14,6))
plt.xticks(rotation= 90)
plot1 = sns.countplot(x= gt1['Region'].sort_values(), data= gt1)
plt.show()

# %% [markdown]
# Middle East and North Africa appear to be the popular recipient of terrorist attacks while Australasia & Oceania seem to be the most peaceful regions for a long time.

# %%
#Checking the highest occuring attact type
plt.figure(figsize=(14,6))
plt.xticks(rotation= 90)
plot1 = sns.countplot(x= gt1['Attack_Type'].sort_values(), data= gt1)
plt.show()

# %% [markdown]
# Bombing and explosion are most popular while hiacking is the least favourite of the terrorists.

# %%
#trying pie chart for attack type data
attack = pd.DataFrame(gt1.groupby('Attack_Type')['Attack_Type'].size().sort_values(ascending=False))
attack.columns = ['Count']

labels = list(attack.index)
#define Seaborn color palette to use
colors = sns.color_palette('pastel')[0:5]

#create pie chart
plt.figure(figsize=(15,15))
plt.pie(attack['Count'], labels = labels, colors = colors, autopct='%.0f%%')
plt.show()

# %% [markdown]
# 49% of the attacks were from Bombing and explosion.

# %%
#Target Type visuals
plt.figure(figsize=(14,6))
plt.xticks(rotation= 90)
plot1 = sns.countplot(x= gt1['Target_Type'].sort_values(), data= gt1)
plt.show()

# %% [markdown]
# Private citizens and property appear to bear the brunt of most terrorism attacks globally.

# %%
#Weapon Type visual
plt.figure(figsize=(14,6))
plt.xticks(rotation= 90)
plot1 = sns.countplot(x= gt1['Weapon'].sort_values(), data=gt1)
plt.show()

# %% [markdown]
# Explosives is the most common weapon which corroborates the data on attack type.

# %%
#determining the success rates of global terrorism attacks
success = pd.DataFrame(gt1.groupby('Success')['Success'].size().sort_values(ascending=False))
success.columns = ['Count']

labels = list(success.index)
#define Seaborn color palette to use
colors = sns.color_palette('pastel')[0:5]

#create pie chart
plt.pie(success['Count'], labels = labels, colors = colors, autopct='%.0f%%')
plt.show()

# %% [markdown]
# 89% of global terrorism attacks were successful over 47 years.

# %% [markdown]
# ## Data preprocessing
# ... First attempt
# Simple preprocessing in 3 steps:
# * Rescaling
# * Standardizing
# * Normailization

# %%
#importing sklearn for preprocessing
from sklearn.preprocessing import MinMaxScaler, StandardScaler, Normalizer

# %%
#Cleaned data from EDA may not be enough for the preprocessing and modelling, 
#so we'll add the numerical columns for each of our categorical columns

df = gt[['country', 'region', 'attacktype1', 'targtype1', 'target1', 'natlty1',
       'gname', 'weaptype1']]
#TREATING FOR MISSING VALUES ON THE NEW DATASET
df['natlty1'].fillna(value=df['natlty1'].median(), inplace=True)
df['target1'].fillna('Unknown',inplace=True)

#merging the previously cleaned dataset to the new one
clean_df = pd.concat([gt1, df], axis=1)
clean_df.head()
# Out:
#    Year  Month  Day  Extended             Country  \
# 0  1970      7    2         0  Dominican Republic
# 1  1970      0    0         0              Mexico
# 2  1970      1    0         0         Philippines
# 3  1970      1    0         0              Greece
# 4  1970      1    0         0               Japan
#
#                         Region           City  Success  Suicide  \
# 0  Central America & Caribbean  Santo Domingo        1        0
# 1                North America    Mexico city        1        0
# 2               Southeast Asia        Unknown        1        0
# 3               Western Europe         Athens        1        0
# 4                    East Asia        Fukouka        1        0
#
#                       Attack_Type                  Target_Type  \
# 0                   Assassination  Private Citizens & Property
# 1     Hostage Taking (Kidnapping)      Government (Diplomatic)
# 2                   Assassination          Journalists & Media
# 3               Bombing/Explosion      Government (Diplomatic)
# 4  Facility/Infrastructure Attack      Government (Diplomatic)
#
#                                       Target_Subtype                   Target  \
# 0                                     Named Civilian             Julio Guzman
# 1  Diplomatic Personnel (outside of embassy, cons...  Nadine Chaval, daughter
# 2                    Radio Journalist/Staff/Facility                 Employee
# 3                                  Embassy/Consulate             U.S. Embassy
# 4                                  Embassy/Consulate           U.S. Consulate
#
#    Target_Nationality                        Attack_Group      Weapon  \
# 0  Dominican Republic                              MANO-D     Unknown
# 1             Belgium  23rd of September Communist League     Unknown
# 2       United States                             Unknown     Unknown
# 3       United States                             Unknown  Explosives
# 4       United States                             Unknown  Incendiary
#
#    No_Of_Killed  No_Of_Wounded  Property  country  region  attacktype1  \
# 0           1.0            0.0         0       58       2            1
# 1           0.0            0.0         0      130       1            6
# 2           1.0            0.0         0      160       5            1
# 3           0.0            0.0         1       78       8            3
# 4           0.0            0.0         1      101       4            7
#
#    targtype1                  target1  natlty1  \
# 0         14             Julio Guzman     58.0
# 1          7  Nadine Chaval, daughter     21.0
# 2         10                 Employee    217.0
# 3          7             U.S. Embassy    217.0
# 4          7           U.S. Consulate    217.0
#
#                                 gname  weaptype1
# 0                              MANO-D         13
# 1  23rd of September Communist League         13
# 2                             Unknown         13
# 3                             Unknown          6
# 4                             Unknown          8

# %%
#checking for missing values
clean_df.isna().sum()
# Out:
# Year                  0
# Month                 0
# Day                   0
# Extended              0
# Country               0
# Region                0
# City                  0
# Success               0
# Suicide               0
# Attack_Type           0
# Target_Type           0
# Target_Subtype        0
# Target                0
# Target_Nationality    0
# Attack_Group          0
# Weapon                0
# No_Of_Killed          0
# No_Of_Wounded         0
# Property              0
# country               0
# region                0
# attacktype1           0
# targtype1             0
# target1               0
# natlty1               0
# gname                 0
# weaptype1             0
# dtype: int64

# %%
#checking for statistics
clean_df.describe().T
# Out:
#                   count         mean         std     min     25%     50%  \
# Year           181691.0  2002.638997   13.259430  1970.0  1991.0  2009.0
# Month          181691.0     6.467277    3.388303     0.0     4.0     6.0
# Day            181691.0    15.505644    8.814045     0.0     8.0    15.0
# Extended       181691.0     0.045346    0.208063     0.0     0.0     0.0
# Success        181691.0     0.889598    0.313391     0.0     1.0     1.0
# Suicide        181691.0     0.036507    0.187549     0.0     0.0     0.0
# No_Of_Killed   181691.0     2.266860   11.227057     0.0     0.0     0.0
# No_Of_Wounded  181691.0     2.883296   34.309747     0.0     0.0     0.0
# Property       181691.0    -0.544556    3.122889    -9.0     0.0     1.0
# country        181691.0   131.968501  112.414535     4.0    78.0    98.0
# region         181691.0     7.160938    2.933408     1.0     5.0     6.0
# attacktype1    181691.0     3.247547    1.915772     1.0     2.0     3.0
# targtype1      181691.0     8.439719    6.653838     1.0     3.0     4.0
# natlty1        181691.0   127.457458   88.949238     4.0    83.0   101.0
# weaptype1      181691.0     6.447325    2.173435     1.0     5.0     6.0
#
#                   75%     max
# Year           2014.0  2017.0
# Month             9.0    12.0
# Day              23.0    31.0
# Extended          0.0     1.0
# Success           1.0     1.0
# Suicide           0.0     1.0
# No_Of_Killed      2.0  1570.0
# No_Of_Wounded     2.0  8191.0
# Property          1.0     1.0
# country         160.0  1004.0
# region           10.0    12.0
# attacktype1       3.0     9.0
# targtype1        14.0    22.0
# natlty1         168.0  1004.0
# weaptype1         6.0    13.0

# %%
#checking feature relationship
clean_df.corr()
# Out:
#                    Year     Month       Day  Extended   Success   Suicide  \
# Year           1.000000  0.000139  0.018254  0.091754 -0.082963  0.137736
# Month          0.000139  1.000000  0.005497 -0.000468 -0.002845  0.003071
# Day            0.018254  0.005497  1.000000 -0.004700 -0.011802  0.003593
# Extended       0.091754 -0.000468 -0.004700  1.000000  0.073233 -0.033961
# Success       -0.082963 -0.002845 -0.011802  0.073233  1.000000 -0.031155
# Suicide        0.137736  0.003071  0.003593 -0.033961 -0.031155  1.000000
# No_Of_Killed   0.021252  0.004031 -0.003225  0.014586  0.049619  0.136385
# No_Of_Wounded  0.017484  0.003178 -0.001082 -0.010175  0.023346  0.096101
# Property      -0.278916 -0.005816 -0.003903 -0.002096 -0.036876 -0.073382
# country       -0.135023 -0.006305  0.003468 -0.020466 -0.037827 -0.050360
# region         0.401384 -0.002999  0.009710  0.038389 -0.030909  0.112672
# attacktype1    0.074153  0.006705 -0.005333  0.272272  0.048408 -0.029962
# targtype1      0.079082 -0.000948 -0.000052  0.011613 -0.059637 -0.023440
# natlty1       -0.019855 -0.004783  0.003724  0.013918 -0.004888 -0.009709
# weaptype1     -0.011737  0.007863 -0.003019  0.207802 -0.008178 -0.039928
#
#                No_Of_Killed  No_Of_Wounded  Property   country    region  \
# Year               0.021252       0.017484 -0.278916 -0.135023  0.401384
# Month              0.004031       0.003178 -0.005816 -0.006305 -0.002999
# Day               -0.003225      -0.001082 -0.003903  0.003468  0.009710
# Extended           0.014586      -0.010175 -0.002096 -0.020466  0.038389
# Success            0.049619       0.023346 -0.036876 -0.037827 -0.030909
# Suicide            0.136385       0.096101 -0.073382 -0.050360  0.112672
# No_Of_Killed       1.000000       0.443326 -0.016816 -0.014383  0.043113
# No_Of_Wounded      0.443326       1.000000 -0.012557 -0.006351  0.019211
# Property          -0.016816      -0.012557  1.000000  0.032051 -0.183279
# country           -0.014383      -0.006351  0.032051  1.000000  0.148597
# region             0.043113       0.019211 -0.183279  0.148597  1.000000
# attacktype1       -0.003448      -0.001424  0.031976 -0.021384  0.007642
# targtype1          0.008466       0.010709  0.004897 -0.019703  0.041396
# natlty1            0.001313      -0.000500 -0.000926  0.598196  0.149508
# weaptype1         -0.001528      -0.011055  0.018999 -0.023708  0.013257
#
#                attacktype1  targtype1   natlty1  weaptype1
# Year              0.074153   0.079082 -0.019855  -0.011737
# Month             0.006705  -0.000948 -0.004783   0.007863
# Day              -0.005333  -0.000052  0.003724  -0.003019
# Extended          0.272272   0.011613  0.013918   0.207802
# Success           0.048408  -0.059637 -0.004888  -0.008178
# Suicide          -0.029962  -0.023440 -0.009709  -0.039928
# No_Of_Killed     -0.003448   0.008466  0.001313  -0.001528
# No_Of_Wounded    -0.001424   0.010709 -0.000500  -0.011055
# Property          0.031976   0.004897 -0.000926   0.018999
# country          -0.021384  -0.019703  0.598196  -0.023708
# region            0.007642   0.041396  0.149508   0.013257
# attacktype1       1.000000   0.014513  0.013605   0.658954
# targtype1         0.014513   1.000000 -0.037783   0.019846
# natlty1           0.013605  -0.037783  1.000000  -0.008848
# weaptype1         0.658954   0.019846 -0.008848   1.000000

# %%
plt.figure(figsize=(16,12))
sns.heatmap(clean_df.corr(), cmap = 'coolwarm', annot = True)
plt.show()

# %%
#The independent variables will be tagged predictors_df while the dependent variable will be tagged target_df
predictors_df = clean_df.drop(columns='Attack_Group')
target_df = gt1['Attack_Group']
predictors_df.shape
# Out:
# (181691, 26)

# %%
target_df.nunique()
# Out:
# 3537

# %%
#The following columns will be dropped from the predictors_df because it has object as it data type, 
#it was done so as to rescale the dataset
independent_var_df = predictors_df.drop(columns = ['Country','Region','City','Attack_Type','Target_Type',
                                                   'Target_Subtype','Target','Target_Nationality','Weapon','gname','target1'], axis=1)
independent_var_df.shape
# Out:
# (181691, 15)

# %%
independent_var_df.dtypes
# Out:
# Year               int64
# Month              int64
# Day                int64
# Extended           int64
# Success            int64
# Suicide            int64
# No_Of_Killed     float64
# No_Of_Wounded    float64
# Property           int64
# country            int64
# region             int64
# attacktype1        int64
# targtype1          int64
# natlty1          float64
# weaptype1          int64
# dtype: object

# %%
#RESCALING OF THE DATASET
#Rescaling of the dataset was done due to the large differnce between the minimum and maximum values across the entire dataset
#For the rescaling the feature_range will be from 0 t0 1 
scaler = MinMaxScaler(feature_range=(0,1))
rescaled_df = pd.DataFrame(scaler.fit_transform(independent_var_df), columns= independent_var_df.columns)
rescaled_df.head()
# Out:
#    Year     Month       Day  Extended  Success  Suicide  No_Of_Killed  \
# 0   0.0  0.583333  0.064516       0.0      1.0      0.0      0.000637
# 1   0.0  0.000000  0.000000       0.0      1.0      0.0      0.000000
# 2   0.0  0.083333  0.000000       0.0      1.0      0.0      0.000637
# 3   0.0  0.083333  0.000000       0.0      1.0      0.0      0.000000
# 4   0.0  0.083333  0.000000       0.0      1.0      0.0      0.000000
#
#    No_Of_Wounded  Property  country    region  attacktype1  targtype1  \
# 0            0.0       0.9    0.054  0.090909        0.000   0.619048
# 1            0.0       0.9    0.126  0.000000        0.625   0.285714
# 2            0.0       0.9    0.156  0.363636        0.000   0.428571
# 3            0.0       1.0    0.074  0.636364        0.250   0.285714
# 4            0.0       1.0    0.097  0.272727        0.750   0.285714
#
#    natlty1  weaptype1
# 0    0.054   1.000000
# 1    0.017   1.000000
# 2    0.213   1.000000
# 3    0.213   0.416667
# 4    0.213   0.583333

# %%
#NORMALIZATION
#From the visualization of the distribution using histogram it can be seen that some features in the dataset were not normal
#Therefore normalization was done to remove skewness from the dataset
scaler = Normalizer()
normalized_df = pd.DataFrame(scaler.fit_transform(rescaled_df), columns= rescaled_df.columns)
normalized_df.head()
# Out:
#    Year     Month       Day  Extended   Success  Suicide  No_Of_Killed  \
# 0   0.0  0.309525  0.034233       0.0  0.530614      0.0      0.000338
# 1   0.0  0.000000  0.000000       0.0  0.550613      0.0      0.000000
# 2   0.0  0.046566  0.000000       0.0  0.558794      0.0      0.000356
# 3   0.0  0.049976  0.000000       0.0  0.599707      0.0      0.000000
# 4   0.0  0.047174  0.000000       0.0  0.566092      0.0      0.000000
#
#    No_Of_Wounded  Property   country    region  attacktype1  targtype1  \
# 0            0.0  0.477552  0.028653  0.048238     0.000000   0.328475
# 1            0.0  0.495552  0.069377  0.000000     0.344133   0.157318
# 2            0.0  0.502915  0.087172  0.203198     0.000000   0.239483
# 3            0.0  0.599707  0.044378  0.381632     0.149927   0.171345
# 4            0.0  0.566092  0.054911  0.154389     0.424569   0.161741
#
#     natlty1  weaptype1
# 0  0.028653   0.530614
# 1  0.009360   0.550613
# 2  0.119023   0.558794
# 3  0.127738   0.249878
# 4  0.120578   0.330220

# %%
normalized_df.describe().T
# Out:
#                   count      mean       std  min       25%       50%  \
# Year           181691.0  0.344432  0.136270  0.0  0.229120  0.387754
# Month          181691.0  0.267048  0.135436  0.0  0.154847  0.270480
# Day            181691.0  0.247688  0.137066  0.0  0.131602  0.250668
# Extended       181691.0  0.019105  0.087969  0.0  0.000000  0.000000
# Success        181691.0  0.443708  0.165159  0.0  0.442536  0.486424
# Suicide        181691.0  0.016343  0.084238  0.0  0.000000  0.000000
# No_Of_Killed   181691.0  0.000705  0.003190  0.0  0.000000  0.000000
# No_Of_Wounded  181691.0  0.000170  0.001712  0.0  0.000000  0.000000
# Property       181691.0  0.424622  0.166443  0.0  0.418172  0.466120
# country        181691.0  0.064400  0.056186  0.0  0.036264  0.051529
# region         181691.0  0.276559  0.127777  0.0  0.196058  0.283244
# attacktype1    181691.0  0.135401  0.105840  0.0  0.066584  0.119727
# targtype1      181691.0  0.173279  0.153427  0.0  0.043609  0.084262
# natlty1        181691.0  0.061942  0.042682  0.0  0.037907  0.052246
# weaptype1      181691.0  0.225236  0.075868  0.0  0.182210  0.203980
#
#                     75%       max
# Year           0.450244  0.842292
# Month          0.378742  0.741281
# Day            0.361875  0.824486
# Extended       0.000000  0.633873
# Success        0.528534  0.856270
# Suicide        0.000000  0.671943
# No_Of_Killed   0.000548  0.398587
# No_Of_Wounded  0.000106  0.375916
# Property       0.512870  0.871719
# country        0.084109  0.567453
# region         0.385201  0.733051
# attacktype1    0.139448  0.636493
# targtype1      0.305726  0.664054
# natlty1        0.086280  0.609662
# weaptype1      0.233330  0.709872

# %%
#writing a new file
#normalized_df.to_csv('normalized_df.csv')
